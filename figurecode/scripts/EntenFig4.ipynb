# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from SuppFig4_lib import *
# %matplotlib inline

# %% [markdown]
# ## Figure S4e - Mutation clustering and tree reconstruction evaluation

# %%
success_data = pd.read_csv('../20221109_Tumour_evo_histories_DATA/SuppFig4_data/S4e_run_success.tsv', sep='\t')

# %%
plot_run_success(success_data)

# %%
data = pd.read_csv('../20221109_Tumour_evo_histories_DATA/SuppFig4_data/S4e_run_eval.tsv', sep='\t')

# %%
plot_evaluation_metrics(data)
